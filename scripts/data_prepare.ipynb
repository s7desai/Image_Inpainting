# %%
import numpy
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import asyncio
import time

# %%
folder = './testSet_resize/'

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def crop_image(file,i):
    img = cv2.imread(folder + '/' + file)
    img[96:96 + 64, 96:96 + 64, :] = 0
    plt.imsave(f'./data_places/{i}.jpg', img)

files = os.listdir(folder)
for i in tqdm(range(41000)):
    crop_image(files[i], i)

print('loop finished')
# Out:
# 100%|██████████████████████████████████| 41000/41000 [00:02<00:00, 20337.38it/s]
# loop finished
# Corrupt JPEG data: bad Huffman code

# %%
files = os.listdir('./data_places/')
len(files)
# Out:
# 41000

# %%
img = cv2.imread('./data_places/' + files[25789])
plt.imshow(img)
