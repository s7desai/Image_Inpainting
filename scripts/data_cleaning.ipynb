# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %%
img = cv2.imread('/home/s7desai/samveed/project/Image_Inpainting/sample_image/sample_dog.jpg')

# %%
img[96:96+64, 96:96+64] = 0
plt.imshow(img)
plt.show()
